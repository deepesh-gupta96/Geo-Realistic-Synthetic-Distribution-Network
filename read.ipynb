# %%
import networkx as nx
import matplotlib.pyplot as plt 
import time

# %%
G= nx.read_graphml("5356625_Pullman.graphml")

# %%
File

# %%
start = time.time()
nx.draw_networkx(G)
end = time.time()
print(end - start)
# Out:
# 8.105513572692871

# %%
G.edges
# Out:
# OutMultiEdgeView([('51478396', '51532522', 0), ('51478396', '51478400', 0), ('51478396', '51506960', 0), ('51478400', '51478396', 0), ('51478400', '51520283', 0), ('51478400', '806082591', 0), ('51478405', '51478409', 0), ('51478405', '51550609', 0), ('51478405', '51489668', 0), ('51478409', '51529329', 0), ('51478409', '3637499335', 0), ('51478409', '51478405', 0), ('51478436', '51525768', 0), ('51478436', '51478440', 0), ('51478436', '51567110', 0), ('51478440', '51536205', 0), ('51478440', '51553382', 0), ('51478440', '51478436', 0), ('51478837', '51478838', 0), ('51478837', '51524264', 0), ('51478837', '51524262', 0), ('51478837', '51552020', 0), ('51478838', '51478839', 0), ('51478838', '51478837', 0), ('51478838', '51519021', 0), ('51478839', '51478838', 0), ('51478839', '51529192', 0), ('51478839', '51535002', 0), ('51478839', '51478841', 0), ('51478841', '51519293', 0), ('51478841', '51478839', 0), ('51478841', '51529187', 0), ('51478850', '51478851', 0), ('51478850', '515320
# ...
